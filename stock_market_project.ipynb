# %%
import requests
from bs4 import BeautifulSoup

def get_stock_data(ticker):
    url = f"https://finance.yahoo.com/quote/{ticker}/financials"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Find the data containing the fundamental
    data = soup.find("M(0) Whs(n) BdEnd Bdc($seperatorColor) D(itb)", {"class": "D(tbrg)"})

    # Extract the data from the table
    results = {}
    #          data.select may also work
    for row in data.find_all("tr"):
        key = row.find("td", {"class": "C($primaryColor) Fz(14px)"}).text
        value = row.find("td", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
        results[key] = value

    return data

ticker = input("Enter the ticker symbol of the stock: ")
results = get_stock_data(ticker)
print(results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 23
#      20     return data
#      22 ticker = input("Enter the ticker symbol of the stock: ")
# ---> 23 results = get_stock_data(ticker)
#      24 print(results)
#
# Cell In[1], line 15, in get_stock_data(ticker)
#      13 results = {}
#      14 #          data.select may also work
# ---> 15 for row in data.find_all("tr"):
#      16     key = row.find("td", {"class": "C($primaryColor) Fz(14px)"}).text
#      17     value = row.find("td", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
from bs4 import BeautifulSoup
import re

ticker = input("Enter the ticker symbol of the stock: ")
url = f"https://stockanalysis.com/stocks/{ticker}/financials/"
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

page = requests.get(url.format(ticker, ticker),headers=headers)

soup = BeautifulSoup(page.text, "html.parser")

pattern = re.compile(r'data-sveltekit-hydrate')
results = soup.find('script', text=pattern).contents[0]

# %%
#beginning of script
start = results[:500]

# %%
# the nd
results[-500:]
# Out:
# '3399000,2597978000,251112000,-15215000],ebitdaMargin:[-.26728195146382105,.33139824712058663,.1965680898580879,-.02850665592475667],depamor:[167504000,98193000,55974000,30201000],ebit:[-1520903000,2499785000,195138000,-45416000],ebitMargin:[-.3003622153017549,.318872741485238,.15275217400493626,-.08509091590395983]},fullCount:3,details:{source:"nasdaq",fiscalYear:"January - December",fiscalYearShort:"Jan - Dec"}},uses:{params:["symbol","routes"],parent:1,url:1}}],\n\t\t\t\t\tform: null\n\t\t\t\t}\n\t\t\t});\n\t\t'

# %%
import json

start = results.find('info')-2
json_results = json.loads(results[start:-1])

# %%
json_results['context'].keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 ext_data['data'].keys()
#
# TypeError: 'int' object is not subscriptable

# %%
annual_is = json_results['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistory']['incomeStatementHistory']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 annual_is = json_results['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistory']['incomeStatementHistory']
#
# TypeError: string indices must be integers

# %%
import requests
from bs4 import BeautifulSoup

def scrape_stock_fundamentals(ticker):
    url = f"https://finance.yahoo.com/quote/{ticker}/financials"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    table = soup.find("div", {"class": "D(tbrg)"})
    rows = table.find_all("div", {"class": "rw-expnded"})
    for row in rows:
        label = row.find("div", {"class": "C($primaryColor) Fz(s) Fw(500)"}).text
        value = row.find("div", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
        print(f"{label}: {value}")

scrape_stock_fundamentals("AAPL")

# %%
import requests
from bs4 import BeautifulSoup

def get_stock_data(ticker):
    url = f"https://finance.yahoo.com/quote/{ticker}/financials"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Find the table containing the fundamental data
    table = soup.find("table", {"class": "W(100%) M(0) BdB Bdc($seperatorColor) Mb(25px)"})

    # Extract the data from the table
    data = {}
    for row in table.find_all("tr"):
        key = row.find("td", {"class": "C($primaryColor) Fz(14px)"}).text
        value = row.find("td", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
        data[key] = value

    return data

ticker = input("Enter the ticker symbol of the stock: ")
data = get_stock_data(ticker)
print(data)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://finance.yahoo.com/quote/AAPL/financials?p=AAPL'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

income_statement_table = soup.find('div', {'class': 'D(tbrg)'})
rows = income_statement_table.find_all('div', {'class': 'rw-expnded'})

for row in rows:
    # Extract the data
    # this depends on the structure of your table, in this example, data is stored in 'div' tag with class 'D(ib) Va(m)'
    # you might have to adjust it based on the structure of the website
    data = row.find_all('div', {'class': 'D(ib) Va(m)'})
    print(data[0].text, data[1].text)

# %%
import requests
import re
from bs4 import BeautifulSoup

def get_stock_data(ticker):
    url = f"https://stockanalysis.com/stocks/{ticker}/financials/"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    
    # Find the table containing the fundamental data // UPDATED may not be needed
    # table = soup.find_all('fi-row', class_='D(tbr)')
    

    # Extract the data from the table
    data = {}
    for row in soup.select(".fi-row"):
        data.append([i.text for i in row.select('[title],[data-test="fin-col"]')])

    p = re.compile(r'\d{1,2}/\d{1,2}/\d{4}')
    headers = ['Breakdown','TTM']
    headers.extend(p.findall(soup.select_one('#Col1-3-Financials-Proxy').text))
    df = pd.DataFrame(data, columns = headers)

    return df

ticker = input("Enter the ticker symbol of the stock: ")
data = get_stock_data(ticker)
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 27
#      24     return df
#      26 ticker = input("Enter the ticker symbol of the stock: ")
# ---> 27 data = get_stock_data(ticker)
#      28 print(data)
#
# Cell In[7], line 21, in get_stock_data(ticker)
#      19 p = re.compile(r'\d{1,2}/\d{1,2}/\d{4}')
#      20 headers = ['Breakdown','TTM']
# ---> 21 headers.extend(p.findall(soup.select_one('#Col1-3-Financials-Proxy').text))
#      22 df = pd.DataFrame(data, columns = headers)
#      24 return df
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup

def get_stock_data(ticker):
    url = f"https://finance.yahoo.com/quote/{ticker}/financials"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Find the table containing the fundamental data
    table = soup.find("table", {"class": "W(100%) M(0) BdB Bdc($seperatorColor) Mb(25px)"})

    # Extract the data from the table
    data = {}
    for row in table.find_all("tr"):
        key = row.find("td", {"class": "C($primaryColor) Fz(14px)"}).text
        value = row.find("td", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
        data[key] = value

    return data

ticker = input("Enter the ticker symbol of the stock: ")
data = get_stock_data(ticker)
print(data)

# %%
import requests
from bs4 import BeautifulSoup

def get_stock_data(ticker):
    url = f"https://stockanalysis.com/stocks/{ticker}/financials/"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Find the table containing the fundamental data
    table = soup.find("w-full whitespace-nowrap", {"class": "w-full whitespace-nowrap"})

    # Extract the data from the table
    data = {}
    for row in table.find_all("tr"):
        key = row.find("th", {"class": "C($primaryColor) Fz(14px)"}).text
        value = row.find("th", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
        data[key] = value

    return data

ticker = input("Enter the ticker symbol of the stock: ")
data = get_stock_data(ticker)
print(data)

# %% [markdown]
# ## XPATH
#
# seems to be limited ot just

# %%
from bs4 import BeautifulSoup
from lxml import etree
import requests


URL = "https://stockanalysis.com/stocks/coin/financials/"

HEADERS = ({'User-Agent':
			'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
			(KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',\
			'Accept-Language': 'en-US, en;q=0.5'})

webpage = requests.get(URL, headers=HEADERS)
soup = BeautifulSoup(webpage.content, "html.parser")
dom = etree.HTML(str(soup))
print(dom.xpath('/html/body/div/div[1]/div[2]/main/div[4]/table/tbody/tr[1]/td[1]/span')[0].text)
# Out:
# Revenue

# %%
import requests
from bs4 import BeautifulSoup

url = f"https://finance.yahoo.com/gainers/"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

# Find the data containing the fundamental
data = soup.find("table", {"class": "W(100%)"})

# Extract the data from the table
results = {}
#          data.select may also work
for row in data.find_all("tr"):
    key = row.find("th", {"class": "Ta(start) Px(10px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m)  Cur(p) Bgc($hoverBgColor):h  Fw(400)!"}).text
    value = row.find("th", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
    results[key] = value


print(results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 15
#      13 #          data.select may also work
#      14 for row in data.find_all("tr"):
# ---> 15     key = row.find("th", {"class": "Ta(start) Px(10px) Fz(xs) Py(5px)! Bgc($lv3BgColor) Va(m)  Cur(p) Bgc($hoverBgColor):h  Fw(400)!"}).text
#      16     value = row.find("th", {"class": "Ta(end) Fw(b) Lh(14px)"}).text
#      17     results[key] = value
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import yfinance as yf


ticker = input("Enter the ticker symbol of the stock: ")


stk_tkr = yf.Ticker(ticker)
stk_tkr.income_stmt
# Out:
#                                                       2021-12-31  \
# Total Revenue                                       7839444000.0
# Operating Revenue                                   7354753000.0
# Cost Of Revenue                                     1267924000.0
# Gross Profit                                        6571520000.0
# Operating Expense                                   3494950000.0
# Selling General And Administration                  1573081000.0
# General And Administrative Expense                   909392000.0
# Other Gand A                                         909392000.0
# Selling And Marketing Expense                        663689000.0
# Research And Development                            1291561000.0
# Other Operating Expenses                             630308000.0
# Operating Income                                    3076570000.0
# Other Income Expense                                 -49623000.0
# Special Income Charges                                       0.0
# Restructuring And Mergern Acquisition                        0.0
# Other Non Operating Income Expenses                  -49623000.0
# Pretax Income                                       3026947000.0
# Tax Provision                                       -597173000.0
# Net Income Common Stockholders                      3096958000.0
# Net Income                                          3624120000.0
# Net Income Including Noncontrolling Interests       3624120000.0
# Net Income Continuous Operations                    3624120000.0
# Otherunder Preferred Stock Dividend                  527162000.0
# Average Dilution Earnings                             93446000.0
# Diluted NI Availto Com Stockholders                 3190404000.0
# Basic EPS                                                  17.47
# Diluted EPS                                                 14.5
# Basic Average Shares                                 177319000.0
# Diluted Average Shares                               219965000.0
# Total Operating Income As Reported                  3076570000.0
# Total Expenses                                      4762874000.0
# Net Income From Continuing And Discontinued Ope...  3624120000.0
# Normalized Income                                   3624120000.0
# EBIT                                                3076570000.0
# Reconciled Cost Of Revenue                          1267924000.0
# Reconciled Depreciation                               63651000.0
# Net Income From Continuing Operation Net Minori...  3624120000.0
# Total Unusual Items Excluding Goodwill                       0.0
# Total Unusual Items                                          0.0
# Normalized EBITDA                                   3140221000.0
# Tax Rate For Calcs                                          0.27
# Tax Effect Of Unusual Items                                  0.0
#
#                                                       2020-12-31   2019-12-31
# Total Revenue                                       1277481000.0  533735000.0
# Operating Revenue                                   1141167000.0  482949000.0
# Cost Of Revenue                                      135514000.0   82055000.0
# Gross Profit                                        1141967000.0  451680000.0
# Operating Expense                                    733016000.0  487323000.0
# Selling General And Administration                   336662000.0  256079000.0
# General And Administrative Expense                   279880000.0  231929000.0
# Other Gand A                                         279880000.0  231929000.0
# Selling And Marketing Expense                         56782000.0   24150000.0
# Research And Development                             271732000.0  185044000.0
# Other Operating Expenses                             124622000.0   46200000.0
# Operating Income                                     408951000.0  -35643000.0
# Other Income Expense                                    248000.0   -9773000.0
# Special Income Charges                                       0.0  -10140000.0
# Restructuring And Mergern Acquisition                        0.0   10140000.0
# Other Non Operating Income Expenses                     248000.0     367000.0
# Pretax Income                                        409199000.0  -45416000.0
# Tax Provision                                         86882000.0  -15029000.0
# Net Income Common Stockholders                       322317000.0  -30387000.0
# Net Income                                           322317000.0  -30387000.0
# Net Income Including Noncontrolling Interests        322317000.0  -30387000.0
# Net Income Continuous Operations                     322317000.0  -30387000.0
# Otherunder Preferred Stock Dividend                          NaN          0.0
# Average Dilution Earnings                                    NaN          0.0
# Diluted NI Availto Com Stockholders                  322317000.0  -30387000.0
# Basic EPS                                                   1.76    -0.166099
# Diluted EPS                                                 1.57    -0.166099
# Basic Average Shares                                 182945000.0  182945000.0
# Diluted Average Shares                               205575000.0  205575000.0
# Total Operating Income As Reported                   408951000.0  -45783000.0
# Total Expenses                                       868530000.0  569378000.0
# Net Income From Continuing And Discontinued Ope...   322317000.0  -30387000.0
# Normalized Income                                    322317000.0  -23602326.0
# EBIT                                                 408951000.0  -35643000.0
# Reconciled Cost Of Revenue                           135514000.0   82055000.0
# Reconciled Depreciation                               30962000.0   16878000.0
# Net Income From Continuing Operation Net Minori...   322317000.0  -30387000.0
# Total Unusual Items Excluding Goodwill                       0.0  -10140000.0
# Total Unusual Items                                          0.0  -10140000.0
# Normalized EBITDA                                    439913000.0   -8625000.0
# Tax Rate For Calcs                                        0.2123       0.3309
# Tax Effect Of Unusual Items                                  0.0   -3355326.0

# %%
from yahoo_fin.stock_info import get_data, tickers_sp500, tickers_nasdaq, tickers_other, get_quote_table, get_day_gainers,get_income_statement

get_day_gainers()
# Out:
#    Symbol                                 Name  Price (Intraday)  Change  \
# 0    DSEY              Diversey Holdings, Ltd.            8.1800  2.2300
# 1    VERX                         Vertex, Inc.           18.5700  3.5600
# 2   RLLCF             Rolls-Royce Holdings plc            0.0087  0.0015
# 3    LFST        LifeStance Health Group, Inc.            5.6000  0.8600
# 4     GOL  Gol Linhas Aéreas Inteligentes S.A.            2.9200  0.3000
# ..    ...                                  ...               ...     ...
# 81    SYM                        Symbotic Inc.           17.4000  0.5300
# 82   LITE               Lumentum Holdings Inc.           53.8500  1.6300
# 83   CIEN                    Ciena Corporation           51.0200  1.5300
# 84   HSAI                          Hesai Group           19.0400  0.5700
# 85   TMHC     Taylor Morrison Home Corporation           36.6100  1.0800
#
#     % Change      Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0      37.48  72394000.0           418958.0  2.738000e+09             NaN
# 1      23.72   1852000.0           176515.0  2.791000e+09             NaN
# 2      20.83   2249000.0          2977000.0  1.896660e+11            0.48
# 3      18.14   4514000.0           405817.0  2.106000e+09             NaN
# 4      11.45   3846000.0          1604000.0  4.671000e+09             NaN
# ..       ...         ...                ...           ...             ...
# 81      3.14    332061.0           310586.0  9.666000e+09             NaN
# 82      3.12   1225000.0           948882.0  3.689000e+09          141.71
# 83      3.09   2115000.0          1655000.0  7.610000e+09           48.59
# 84      3.09    268634.0           927622.0  2.457000e+09             NaN
# 85      3.04    735236.0           914894.0  3.993000e+09            4.07
#
# [86 rows x 9 columns]

# %%
# NOT WOKRING 3/8/23
import yfinance as yf


stk_tkr = yf.Ticker('AAPL')
stk_tkr.income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 import yfinance as yf
#       5 stk_tkr = yf.Ticker('AAPL')
# ----> 6 stk_tkr.income_stmt
#
# File d:\miniconda3\lib\site-packages\yfinance\ticker.py:158, in Ticker.income_stmt(self)
#     156 @property
#     157 def income_stmt(self) -> _pd.DataFrame:
# --> 158     return self.get_income_stmt(pretty=True)
#
# File d:\miniconda3\lib\site-packages\yfinance\base.py:993, in TickerBase.get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#     991     data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#     992 else:
# --> 993     data = self._fundamentals.financials.get_income_time_series(freq=freq, proxy=proxy)
#     995 if pretty:
#     996     data = data.copy()
#
# File d:\miniconda3\lib\site-packages\yfinance\scrapers\fundamentals.py:113, in Financials.get_income_time_series(self, freq, proxy)
#     111 res = self._income_time_series
#     112 if freq not in res:
# --> 113     res[freq] = self._fetch_time_series("income", freq, proxy=None)
#     114 return res[freq]
#
# File d:\miniconda3\lib\site-packages\yfinance\scrapers\fundamentals.py:142, in Financials._fetch_time_series(self, name, timescale, proxy)
#     139     raise ValueError("Illegal argument: timescale must be one of: {}".format(allowed_names))
#     141 try:
# --> 142     statement = self._create_financials_table(name, timescale, proxy)
#     144     if statement is not None:
#     145         return statement
#
# File d:\miniconda3\lib\site-packages\yfinance\scrapers\fundamentals.py:155, in Financials._create_financials_table(self, name, timescale, proxy)
#     151 if name == "income":
#     152     # Yahoo stores the 'income' table internally under 'financials' key
#     153     name = "financials"
# --> 155 keys = self._get_datastore_keys(name, proxy)
#     156 try:
#     157     return self.get_financials_time_series(timescale, keys, proxy)
#
# File d:\miniconda3\lib\site-packages\yfinance\scrapers\fundamentals.py:162, in Financials._get_datastore_keys(self, sub_page, proxy)
#     161 def _get_datastore_keys(self, sub_page, proxy) -> list:
# --> 162     data_stores = self._data.get_json_data_stores(sub_page, proxy)
#     164     # Step 1: get the keys:
#     165     def _finditem1(key, obj):
#
# File d:\miniconda3\lib\site-packages\yfinance\data.py:40, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      38 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      39 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 40 return func(*args, **kwargs)
#
# File d:\miniconda3\lib\site-packages\yfinance\data.py:202, in TickerData.get_json_data_stores(self, sub_page, proxy)
#     198     return {}
#     200 data = json.loads(json_str)
# --> 202 stores = decrypt_cryptojs_aes_stores(data)
#     203 if stores is None:
#     204     # Maybe Yahoo returned old format, not encrypted
#     205     if "context" in data and "dispatcher" in data["context"]:
#
# File d:\miniconda3\lib\site-packages\yfinance\data.py:73, in decrypt_cryptojs_aes_stores(data)
#      71     for i in range(1, len(new_keys)):
#      72         msg += f" , '{k_str}'->{type(data[k])}"
# ---> 73     raise Exception(msg)
#      74 password_key = new_keys[0]
#      75 password = data[password_key]
#
# Exception: Yahoo has again changed data format, yfinance now unsure which key(s) is for decryption: '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str'> , '6d8d1e8358dd'-><class 'str' ...
